# %%
import requests
import pandas as pd
header = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
query = '?query='
key = '&key=AIzaSyAShXNYbYAIDmj2h1R5vxjh4Wrw6eDqpxc'
near = '%20near%20'
url = header + query + key
categories = ["restaurants","parks","museums"]
locations = ["columbia%20university", "upper%20west%20side", "morningside%29heights", "harlem"]

def mapsQueryToDf(cat,loc):
    url = header + query + cat + near + loc + key
    df = pd.read_json(url, typ='series')
    return pd.DataFrame(df.results)

df = pd.DataFrame()

for category in categories:
    for location in locations:
        df = pd.concat([df,mapsQueryToDf(category,location)])

# %%
print(df)

df.to_csv('out.csv', index=False)
# Out:
#        business_status                                  formatted_address  \
# 0          OPERATIONAL   2893 Broadway, New York, NY 10025, United States
# 1          OPERATIONAL  2896 Broadway, Manhattan, NY 10025, United States
# 2          OPERATIONAL  1239 Amsterdam Ave, New York, NY 10027, United...
# 3          OPERATIONAL   2937 Broadway, New York, NY 10025, United States
# 4          OPERATIONAL  519 W 114th St, New York, NY 10027, United States
# ..                 ...                                                ...
# 15  CLOSED_TEMPORARILY  231 W 142nd St, New York, NY 10030, United States
# 16         OPERATIONAL  610 Exterior Street, Bronx, NY 10451, United S...
# 17         OPERATIONAL  2 Lincoln Square, New York, NY 10023, United S...
# 18  CLOSED_TEMPORARILY  162 1/2 E 104th St, New York, NY 10029, United...
# 19         OPERATIONAL    1000 5th Ave, New York, NY 10028, United States
#
#                                              geometry  \
# 0   {'location': {'lat': 40.8059222, 'lng': -73.96...
# 1   {'location': {'lat': 40.8058205, 'lng': -73.96...
# 2   {'location': {'lat': 40.809733, 'lng': -73.958...
# 3   {'location': {'lat': 40.8072844, 'lng': -73.96...
# 4   {'location': {'lat': 40.8056922, 'lng': -73.96...
# ..                                                ...
# 15  {'location': {'lat': 40.8205191, 'lng': -73.94...
# 16  {'location': {'lat': 40.8205231, 'lng': -73.93...
# 17  {'location': {'lat': 40.7732389, 'lng': -73.98...
# 18  {'location': {'lat': 40.7906833, 'lng': -73.94...
# 19  {'location': {'lat': 40.7794366, 'lng': -73.96...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                ...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                               name        opening_hours  \
# 0           Community Food & Juice   {'open_now': True}
# 1                    Junzi Kitchen   {'open_now': True}
# 2                          Massawa   {'open_now': True}
# 3                       sweetgreen   {'open_now': True}
# 4             John Jay Dining Hall  {'open_now': False}
# ..                             ...                  ...
# 15      Freedom Journey Foundation                  NaN
# 16        Universal Hip Hop Museum  {'open_now': False}
# 17        American Folk Art Museum  {'open_now': False}
# 18  The NYC Graffiti Events Center                  NaN
# 19  The Metropolitan Museum of Art  {'open_now': False}
#
#                                                photos  \
# 0   [{'height': 3024, 'html_attributions': ['<a hr...
# 1   [{'height': 3202, 'html_attributions': ['<a hr...
# 2   [{'height': 3744, 'html_attributions': ['<a hr...
# 3   [{'height': 1350, 'html_attributions': ['<a hr...
# 4   [{'height': 3024, 'html_attributions': ['<a hr...
# ..                                                ...
# 15  [{'height': 2448, 'html_attributions': ['<a hr...
# 16  [{'height': 1103, 'html_attributions': ['<a hr...
# 17  [{'height': 3024, 'html_attributions': ['<a hr...
# 18  [{'height': 4032, 'html_attributions': ['<a hr...
# 19  [{'height': 3088, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJnSR09Dv2wokRz_B9gF6v96c
# 1   ChIJ92N9DDz2wokR38VWvxg3qrE
# 2   ChIJizsMQxX2wokRSD5_pzmhaYg
# 3   ChIJ3W_Lrz72wokRy3BEhF4s20U
# 4   ChIJWfux0j32wokRPzoTR-HSfL8
# ..                          ...
# 15  ChIJQ7Q6KXr2wokRTlBHplEUkGo
# 16  ChIJ4RnolMj1wokRTskczpb-_s4
# 17  ChIJEeD6FPVYwokRgs0ZbWMrrzk
# 18  ChIJbXuvBBr3wokRpMS1cr9OWTE
# 19  ChIJb8Jg9pZYwokR-qHGtvSkLzs
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'R24M+9M New York', 'global_...          2.0     4.3
# 1   {'compound_code': 'R24M+8W New York', 'global_...          2.0     4.4
# 2   {'compound_code': 'R25R+VH New York', 'global_...          2.0     4.4
# 3   {'compound_code': 'R24P+W3 New York', 'global_...          2.0     4.1
# 4   {'compound_code': 'R24Q+74 New York', 'global_...          NaN     4.3
# ..                                                ...          ...     ...
# 15  {'compound_code': 'R3C5+66 New York', 'global_...          NaN     5.0
# 16  {'compound_code': 'R3C9+6W New York', 'global_...          NaN     4.7
# 17  {'compound_code': 'Q2F9+7C New York', 'global_...          NaN     4.3
# 18  {'compound_code': 'Q3R3+76 New York', 'global_...          NaN     5.0
# 19  {'compound_code': 'Q2HP+QP New York', 'global_...          3.0     4.8
#
#                       reference  \
# 0   ChIJnSR09Dv2wokRz_B9gF6v96c
# 1   ChIJ92N9DDz2wokR38VWvxg3qrE
# 2   ChIJizsMQxX2wokRSD5_pzmhaYg
# 3   ChIJ3W_Lrz72wokRy3BEhF4s20U
# 4   ChIJWfux0j32wokRPzoTR-HSfL8
# ..                          ...
# 15  ChIJQ7Q6KXr2wokRTlBHplEUkGo
# 16  ChIJ4RnolMj1wokRTskczpb-_s4
# 17  ChIJEeD6FPVYwokRgs0ZbWMrrzk
# 18  ChIJbXuvBBr3wokRpMS1cr9OWTE
# 19  ChIJb8Jg9pZYwokR-qHGtvSkLzs
#
#                                                 types  user_ratings_total  \
# 0   [restaurant, food, point_of_interest, establis...                 819
# 1   [meal_delivery, meal_takeaway, restaurant, foo...                 275
# 2   [restaurant, food, point_of_interest, establis...                 315
# 3   [meal_takeaway, restaurant, food, point_of_int...                 371
# 4   [restaurant, food, point_of_interest, establis...                 140
# ..                                                ...                 ...
# 15         [museum, point_of_interest, establishment]                   1
# 16  [museum, tourist_attraction, point_of_interest...                  62
# 17  [tourist_attraction, museum, point_of_interest...                 461
# 18         [museum, point_of_interest, establishment]                   3
# 19  [art_gallery, tourist_attraction, museum, poin...               62208
#
#    permanently_closed
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 15               True
# 16                NaN
# 17                NaN
# 18               True
# 19                NaN
#
# [225 rows x 15 columns]
